# %% [markdown]
# The metric we have chosen for this project is the healthiest neighborhood in Pittsburgh in order to decide who will be recruited to a utopian society on Neptune. In order to decide which neighborhood is the healthiest, I will be focusing on the health of children in Pittsburgh. While children may not initially seem to be an important factor in the general health of a neighborhood, in order to recruit larger families to out new society, we would need their children to be healthy too. One way to measure this would be by the physical activity of children and one way to measure physical activity is by measuring the amount of playgrounds per neighborhood. Some other metrics I considered looking at were parks in general as well as public fitness locations, such as pools or gyms. In the end however, I decided to go with playgrounds so that I could focus on the specific demographic of children.

# %% [markdown]
# The metric I am focusing on is playgrounds per neighborhood. I will be measuring the amount of playgrounds per neighborhood as well as the amount of children enrolled in schools per neighborhood. In theory, the more playgrounds per neighborhood, the more children will be outside engaging in physcial activity, and the more times children are engaging in physical activity, the more healthier they will be. Ideally, the smaller the population to playground ratio, the healthier the neighborhood because it would be less likely for the playgrounds to become too overcrowded. Therefore, the best neighborhood will be the one with a small population and high amount of playgrounds. The dataset I will be using for this then will be playgrounds per neighborhood and school enrollemt per neighborhood.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import geopandas

# %%
pg=pd.read_csv("playgrounds.tsv", sep='\t')

# %%
pg.head()
# Out:
#            id                      name  type maintenance_responsibility  \
# 0   731501774      Able Long Playground   NaN            Parks - Western
# 1  1461276747  Albert Graham Playground   NaN           Parks - Schenley
# 2  1860709784         Alpine Playground   NaN           Parks - Northern
# 3  1770671485          Alton Playground   NaN            Parks - Western
# 4    18942817          Ammon Playground   NaN           Parks - Schenley
#
#                       park       street  \
# 0           Able Long Park    COAST AVE
# 1  Albert Turk Graham Park  FORESIDE PL
# 2      Alpine Gardens Park   ALPINE AVE
# 3               Alton Park   ANDICK WAY
# 4               Ammon Park    MEMORY LN
#
#                                                image       neighborhood  \
# 0  https://tools.wprdc.org/images/pittsburgh/play...          Beechview
# 1  https://tools.wprdc.org/images/pittsburgh/play...   Crawford-Roberts
# 2  https://tools.wprdc.org/images/pittsburgh/play...  Central Northside
# 3  https://tools.wprdc.org/images/pittsburgh/play...          Beechview
# 4  https://tools.wprdc.org/images/pittsburgh/play...  Bedford Dwellings
#
#    council_district  ward        tract  public_works_division  pli_division  \
# 0                 4    19  42003192000                      5            19
# 1                 6     3  42003030500                      3             3
# 2                 6    25  42003250300                      1            25
# 3                 4    19  42003191600                      5            19
# 4                 6     5  42003050900                      3             5
#
#    police_zone fire_zone   latitude  longitude
# 0            6      4-28  40.408365 -80.028445
# 1            2       2-1  40.440519 -79.984137
# 2            1      1-21  40.457707 -80.012952
# 3            6      4-28  40.414137 -80.021605
# 4            2       2-5  40.449037 -79.978064

# %%
p=pg.groupby("neighborhood").count()
p
#new dataframe organized by amount of parks per neighborhood
# Out:
#                      id  name  type  maintenance_responsibility  park  street  \
# neighborhood
# Allegheny Center      4     4     0                           4     4       4
# Allentown             1     1     0                           1     1       1
# Banksville            1     1     0                           1     1       1
# Bedford Dwellings     1     1     0                           1     1       1
# Beechview             5     5     0                           5     5       5
# ...                  ..   ...   ...                         ...   ...     ...
# Upper Lawrenceville   3     3     0                           2     3       3
# West End              1     1     0                           1     1       1
# West Oakland          1     1     0                           1     1       1
# Westwood              1     1     0                           1     1       1
# Windgap               1     1     0                           1     1       1
#
#                      image  council_district  ward  tract  \
# neighborhood
# Allegheny Center         4                 4     4      4
# Allentown                1                 1     1      1
# Banksville               1                 1     1      1
# Bedford Dwellings        1                 1     1      1
# Beechview                5                 5     5      5
# ...                    ...               ...   ...    ...
# Upper Lawrenceville      2                 3     3      3
# West End                 1                 1     1      1
# West Oakland             1                 1     1      1
# Westwood                 1                 1     1      1
# Windgap                  1                 1     1      1
#
#                      public_works_division  pli_division  police_zone  \
# neighborhood
# Allegheny Center                         4             4            4
# Allentown                                1             1            1
# Banksville                               1             1            1
# Bedford Dwellings                        1             1            1
# Beechview                                5             5            5
# ...                                    ...           ...          ...
# Upper Lawrenceville                      3             3            3
# West End                                 1             1            1
# West Oakland                             1             1            1
# Westwood                                 1             1            1
# Windgap                                  1             1            1
#
#                      fire_zone  latitude  longitude
# neighborhood
# Allegheny Center             4         4          4
# Allentown                    1         1          1
# Banksville                   1         1          1
# Bedford Dwellings            1         1          1
# Beechview                    5         5          5
# ...                        ...       ...        ...
# Upper Lawrenceville          3         3          3
# West End                     1         1          1
# West Oakland                 1         1          1
# Westwood                     1         1          1
# Windgap                      1         1          1
#
# [68 rows x 16 columns]

# %%
pg['neighborhood'].value_counts().plot( kind='bar', figsize=(14,8) )
plt.title("Playgrounds per Neighborhood")
plt.xlabel("Neighborhood")
plt.ylabel("Number of Playgrounds")
#bar graph of the amount of parks per neighborhood
# Out:
# Text(0, 0.5, 'Number of Playgrounds')

# %% [markdown]
# This is the amount of playgrounds per neighborhood, Squirrel Hill South is the obvious winner here with 8 playgrounds.

# %%
p["park"].value_counts().sort_index().plot(kind='bar', rot=0)
#amount of neighborhoods that have certain amount of parks, interesting to see

# %% [markdown]
# This is the frequency of how many playgrounds a neighborhood has. Most neighborhoods only have 1.

# %%
play = p.groupby("neighborhood").sum()['park']
play.sort_values(ascending=False)
# Out:
# neighborhood
# Squirrel Hill South    8
# Beechview              5
# South Side Slopes      5
# Allegheny Center       4
# Sheraden               4
#                       ..
# Oakwood                1
# Perry North            1
# Perry South            1
# Windgap                1
# East Allegheny         0
# Name: park, Length: 68, dtype: int64

# %%
neighborhoods = geopandas.read_file("Neighborhoods/Neighborhoods_.shp")

# %%
pg_map = neighborhoods.merge(play, how='left', left_on='hood', right_on='neighborhood')
pg_map[['hood','park','geometry']].head()
# Out:
#                hood  park                                           geometry
# 0   Central Oakland   1.0  POLYGON ((-79.95304 40.44203, -79.95302 40.442...
# 1     North Oakland   NaN  POLYGON ((-79.95455 40.45882, -79.95427 40.458...
# 2      West Oakland   1.0  POLYGON ((-79.96230 40.44294, -79.96220 40.442...
# 3  Crawford-Roberts   3.0  POLYGON ((-79.98275 40.44641, -79.98273 40.446...
# 4    Strip District   1.0  POLYGON ((-79.97494 40.45629, -79.97484 40.456...

# %%
pg_map.plot(column='park', 
               cmap='OrRd',              
               edgecolor="white",        
               legend=True,             
               legend_kwds={'label': "Number of Playgrounds"}, 
               figsize=(15, 10),         
               missing_kwds={"color": "lightgrey"}
               )

# %% [markdown]
# Now, although Squirrel Hill is an obvious winner here, it is also important to look at population because where there are more kids, there will also likely be more playgrounds. To combat this, I will be looking at school enrollment populations for kids in grade school.

# %%
se=pd.read_csv("school_enrollment.csv")

# %%
se.head()
# Out:
#         Neighborhood  Id  Estimate; Total:  Margin of Error; Total:  \
# 0   Allegheny Center   1            1389.0               193.000000
# 1     Allegheny West   2             343.0                96.000000
# 2          Allentown   3            2520.0               449.503059
# 3          Arlington   4            1823.0               342.302498
# 4  Arlington Heights   5             213.0               115.000000
#
#    Estimate; Enrolled in school:  Margin of Error; Enrolled in school:  \
# 0                          394.0                            120.000000
# 1                           61.0                             44.000000
# 2                          965.0                            312.800256
# 3                          427.0                            127.722355
# 4                           40.0                             49.000000
#
#    Estimate; Enrolled in school: - Enrolled in nursery school, preschool  \
# 0                                               48.0
# 1                                                0.0
# 2                                               19.0
# 3                                                7.0
# 4                                               28.0
#
#    Margin of Error; Enrolled in school: - Enrolled in nursery school, preschool  \
# 0                                          29.000000
# 1                                          10.000000
# 2                                          22.825424
# 3                                          17.916473
# 4                                          49.000000
#
#    Estimate; Enrolled in school: - Enrolled in kindergarten  \
# 0                                                0.0
# 1                                                0.0
# 2                                               23.0
# 3                                                6.0
# 4                                                0.0
#
#    Margin of Error; Enrolled in school: - Enrolled in kindergarten  ...  \
# 0                                          10.000000                ...
# 1                                          10.000000                ...
# 2                                          28.722813                ...
# 3                                          17.916473                ...
# 4                                          10.000000                ...
#
#    Estimate; Enrolled in school: - Enrolled in grade 11  \
# 0                                                0.0
# 1                                                9.0
# 2                                               41.0
# 3                                               37.0
# 4                                                0.0
#
#    Margin of Error; Enrolled in school: - Enrolled in grade 11  \
# 0                                          10.000000
# 1                                          12.000000
# 2                                          53.823787
# 3                                          27.000000
# 4                                          10.000000
#
#    Estimate; Enrolled in school: - Enrolled in grade 12  \
# 0                                               21.0
# 1                                                0.0
# 2                                               81.0
# 3                                               17.0
# 4                                                0.0
#
#    Margin of Error; Enrolled in school: - Enrolled in grade 12  \
# 0                                          32.000000
# 1                                          10.000000
# 2                                          72.718636
# 3                                          27.856777
# 4                                          10.000000
#
#    Estimate; Enrolled in school: - Enrolled in college, undergraduate years  \
# 0                                              150.0
# 1                                                2.0
# 2                                              125.0
# 3                                              142.0
# 4                                               12.0
#
#    Margin of Error; Enrolled in school: - Enrolled in college, undergraduate years  \
# 0                                          60.000000
# 1                                           4.000000
# 2                                          87.120606
# 3                                          69.231496
# 4                                          14.000000
#
#    Estimate; Enrolled in school: - Graduate or professional school  \
# 0                                               51.0
# 1                                               25.0
# 2                                               74.0
# 3                                               16.0
# 4                                                0.0
#
#    Margin of Error; Enrolled in school: - Graduate or professional school  \
# 0                                          35.000000
# 1                                          22.000000
# 2                                         101.469207
# 3                                          18.493242
# 4                                          10.000000
#
#    Estimate; Not enrolled in school  Margin of Error; Not enrolled in school
# 0                             995.0                               135.000000
# 1                             282.0                                74.000000
# 2                            1555.0                               267.807767
# 3                            1396.0                               267.159129
# 4                             173.0                                87.000000
#
# [5 rows x 40 columns]

# %% [markdown]
# So this dataframe has a lot more than just grade school populations. Therefore, I will make a new dataset with just grade school.

# %%
gs = se.loc[:,["Neighborhood","Estimate; Enrolled in school: - Enrolled in kindergarten","Estimate; Enrolled in school: - Enrolled in grade 1","Estimate; Enrolled in school: - Enrolled in grade 2","Estimate; Enrolled in school: - Enrolled in grade 3","Estimate; Enrolled in school: - Enrolled in grade 4","Estimate; Enrolled in school: - Enrolled in grade 5"]]
gs
# Out:
#            Neighborhood  \
# 0      Allegheny Center
# 1        Allegheny West
# 2             Allentown
# 3             Arlington
# 4     Arlington Heights
# ..                  ...
# 86  Upper Lawrenceville
# 87             West End
# 88         West Oakland
# 89             Westwood
# 90              Windgap
#
#     Estimate; Enrolled in school: - Enrolled in kindergarten  \
# 0                                                 0.0
# 1                                                 0.0
# 2                                                23.0
# 3                                                 6.0
# 4                                                 0.0
# ..                                                ...
# 86                                               18.0
# 87                                                0.0
# 88                                                0.0
# 89                                               65.0
# 90                                                9.0
#
#     Estimate; Enrolled in school: - Enrolled in grade 1  \
# 0                                                46.0
# 1                                                16.0
# 2                                               120.0
# 3                                                 5.0
# 4                                                 0.0
# ..                                                ...
# 86                                                0.0
# 87                                                0.0
# 88                                               22.0
# 89                                               22.0
# 90                                               24.0
#
#     Estimate; Enrolled in school: - Enrolled in grade 2  \
# 0                                                 0.0
# 1                                                 0.0
# 2                                                55.0
# 3                                                24.0
# 4                                                 0.0
# ..                                                ...
# 86                                               29.0
# 87                                                0.0
# 88                                                0.0
# 89                                               10.0
# 90                                                5.0
#
#     Estimate; Enrolled in school: - Enrolled in grade 3  \
# 0                                                 0.0
# 1                                                 0.0
# 2                                                96.0
# 3                                                36.0
# 4                                                 0.0
# ..                                                ...
# 86                                               34.0
# 87                                                0.0
# 88                                                7.0
# 89                                               55.0
# 90                                                0.0
#
#     Estimate; Enrolled in school: - Enrolled in grade 4  \
# 0                                                33.0
# 1                                                 0.0
# 2                                                57.0
# 3                                                 9.0
# 4                                                 0.0
# ..                                                ...
# 86                                               50.0
# 87                                                0.0
# 88                                                0.0
# 89                                                0.0
# 90                                                0.0
#
#     Estimate; Enrolled in school: - Enrolled in grade 5
# 0                                                 0.0
# 1                                                 0.0
# 2                                                60.0
# 3                                                19.0
# 4                                                 0.0
# ..                                                ...
# 86                                               12.0
# 87                                                0.0
# 88                                                6.0
# 89                                               53.0
# 90                                               61.0
#
# [91 rows x 7 columns]

# %% [markdown]
# This much better, but it should be organized by neighborhood and should have a total population.

# %%
g = gs.groupby("Neighborhood").sum()
g['total'] = g['Estimate; Enrolled in school: - Enrolled in kindergarten'] + g['Estimate; Enrolled in school: - Enrolled in grade 1'] + g['Estimate; Enrolled in school: - Enrolled in grade 2'] + g['Estimate; Enrolled in school: - Enrolled in grade 3'] + g['Estimate; Enrolled in school: - Enrolled in grade 4'] + g['Estimate; Enrolled in school: - Enrolled in grade 5']
g
# Out:
#                      Estimate; Enrolled in school: - Enrolled in kindergarten  \
# Neighborhood
# Allegheny Center                                                   0.0
# Allegheny West                                                     0.0
# Allentown                                                         23.0
# Arlington                                                          6.0
# Arlington Heights                                                  0.0
# ...                                                                ...
# Upper Lawrenceville                                               18.0
# West End                                                           0.0
# West Oakland                                                       0.0
# Westwood                                                          65.0
# Windgap                                                            9.0
#
#                      Estimate; Enrolled in school: - Enrolled in grade 1  \
# Neighborhood
# Allegheny Center                                                  46.0
# Allegheny West                                                    16.0
# Allentown                                                        120.0
# Arlington                                                          5.0
# Arlington Heights                                                  0.0
# ...                                                                ...
# Upper Lawrenceville                                                0.0
# West End                                                           0.0
# West Oakland                                                      22.0
# Westwood                                                          22.0
# Windgap                                                           24.0
#
#                      Estimate; Enrolled in school: - Enrolled in grade 2  \
# Neighborhood
# Allegheny Center                                                   0.0
# Allegheny West                                                     0.0
# Allentown                                                         55.0
# Arlington                                                         24.0
# Arlington Heights                                                  0.0
# ...                                                                ...
# Upper Lawrenceville                                               29.0
# West End                                                           0.0
# West Oakland                                                       0.0
# Westwood                                                          10.0
# Windgap                                                            5.0
#
#                      Estimate; Enrolled in school: - Enrolled in grade 3  \
# Neighborhood
# Allegheny Center                                                   0.0
# Allegheny West                                                     0.0
# Allentown                                                         96.0
# Arlington                                                         36.0
# Arlington Heights                                                  0.0
# ...                                                                ...
# Upper Lawrenceville                                               34.0
# West End                                                           0.0
# West Oakland                                                       7.0
# Westwood                                                          55.0
# Windgap                                                            0.0
#
#                      Estimate; Enrolled in school: - Enrolled in grade 4  \
# Neighborhood
# Allegheny Center                                                  33.0
# Allegheny West                                                     0.0
# Allentown                                                         57.0
# Arlington                                                          9.0
# Arlington Heights                                                  0.0
# ...                                                                ...
# Upper Lawrenceville                                               50.0
# West End                                                           0.0
# West Oakland                                                       0.0
# Westwood                                                           0.0
# Windgap                                                            0.0
#
#                      Estimate; Enrolled in school: - Enrolled in grade 5  \
# Neighborhood
# Allegheny Center                                                   0.0
# Allegheny West                                                     0.0
# Allentown                                                         60.0
# Arlington                                                         19.0
# Arlington Heights                                                  0.0
# ...                                                                ...
# Upper Lawrenceville                                               12.0
# West End                                                           0.0
# West Oakland                                                       6.0
# Westwood                                                          53.0
# Windgap                                                           61.0
#
#                      total
# Neighborhood
# Allegheny Center      79.0
# Allegheny West        16.0
# Allentown            411.0
# Arlington             99.0
# Arlington Heights      0.0
# ...                    ...
# Upper Lawrenceville  143.0
# West End               0.0
# West Oakland          35.0
# Westwood             205.0
# Windgap               99.0
#
# [91 rows x 7 columns]

# %%
k = g.groupby("Neighborhood").sum()['total']
k.sort_values(ascending=False)
# Out:
# Neighborhood
# Squirrel Hill South          983.0
# Brookline                    878.0
# Carrick                      807.0
# Sheraden                     604.0
# Squirrel Hill North          574.0
#                              ...
# Ridgemont                      0.0
# North Shore                    0.0
# West End                       0.0
# Arlington Heights              0.0
# Central Business District      0.0
# Name: total, Length: 91, dtype: float64

# %%
k.plot(kind='bar', figsize=(18,8))
plt.title("Grade School Population per Neighborhood")
plt.xlabel("Neighborhood")
plt.ylabel("Grade School Population")
# Out:
# Text(0, 0.5, 'Grade School Population')

# %% [markdown]
# The total student enrollments for grades k-5 per neighborhood

# %% [markdown]
# Now time to make a map:

# %%
neighborhoods = geopandas.read_file("Neighborhoods/Neighborhoods_.shp")
gs_map = neighborhoods.merge(k, how='left', left_on='hood', right_on='Neighborhood')
gs_map[['hood','total','geometry']].head()
# Out:
#                hood  total                                           geometry
# 0   Central Oakland   12.0  POLYGON ((-79.95304 40.44203, -79.95302 40.442...
# 1     North Oakland  135.0  POLYGON ((-79.95455 40.45882, -79.95427 40.458...
# 2      West Oakland   35.0  POLYGON ((-79.96230 40.44294, -79.96220 40.442...
# 3  Crawford-Roberts  152.0  POLYGON ((-79.98275 40.44641, -79.98273 40.446...
# 4    Strip District    8.0  POLYGON ((-79.97494 40.45629, -79.97484 40.456...

# %%
gs_map.plot(column='total',
              cmap='OrRd',              
              edgecolor="white",        
               legend=True,             
               legend_kwds={'label': "Grade School Population"}, 
                figsize=(15, 10),         
           )

# %% [markdown]
# ## Data Analysis

# %% [markdown]
# For this analysis, I will take the top 3 neighborhoods in terms of amount of playgrounds and compare it to their student population. I am only taking the top 3 because there still needs to be a high enough amount of playgrounds to qualify as the "best neighborhood due to amount of playgrounds", so I will only be taking the neighborhoods that have 5 or more playgrounds. I will take the population and divide it by the amount of playgrounds per neighborhood (as this would be the amount of children per playground if every child was at a playground per neighborhood). The neighborhood with the smallest number will therefore have the best ratio of children to playground and be the winner of this metric.

# %% [markdown]
# **Squirrel Hill South:**
#    - Playgrounds: 8
#    - Population: 983
#    - Score: 122.875
#    - Rank: 3

# %% [markdown]
# **Beechview:**
#    - Playgrounds: 5
#    - Population: 446
#    - Score: 89.2
#    - Rank: 2

# %% [markdown]
# **South Side Slopes:**
#    - Playgrounds: 5
#    - Population: 118
#    - Score: 23.6
#    - Rank: 1

# %% [markdown]
# ## Conclusion

# %% [markdown]
# So, by this analysis, I can conclude that the neighborhood with the smallest child population to playground ratio is South Side Slopes. Thus, by the metric described earlier, this would be the healthiest neighborhood by this dataset. The neighborhood in second place would be Beechview and and third place Squirrel Hill South.

# %% [markdown]
# Most neighborhoods only have one park, with 39 neighborhoods included in the dataset only having one. 15 neighborhoods have two parks, eight neighborhoods have three parks, four neighborhoods have four parks, two neighborhoods have five parks, and only one neighborhood has eight parks.

# %% [markdown]
# While I do not know much about Pittsburgh neighborhoods, I have heard that Squirrel Hill North is a generally nice neighborhood, and from the few times I have visited it, I would agree. The neighborhood is mostly suburban, so it would make sense that there are a lot of playgrounds. However, many of the other neighborhoods included are also suburban, and considering how many more parks Squirrel Hill North has than other neighborhoods, I think it is safe to say that it is the healthiest neighborhood in terms of physical activity in children.
