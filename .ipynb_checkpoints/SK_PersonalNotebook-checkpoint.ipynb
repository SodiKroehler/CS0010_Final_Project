# %% [markdown]
# # Grade Elevation Changes By Neighborhood
#
# ## Kroehler, Sodi's Analysis Notebook
#
# This document looks at the amounts of grade elevation changes, as marked by stairs, per neighbourhood.
#
# First, I loaded a dataset containing all public stairs in the greater Pittsburg area.

# %%
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt

stairs = pd.read_csv("https://data.wprdc.org/datastore/dump/43f40ca4-2211-4a12-8b4f-4d052662bb64")

# %%
stairs.describe()
# Out:
#                  id       length  number_of_steps  schools_count  \
# count  1.107000e+03   870.000000       753.000000     566.000000
# mean   1.082821e+09   166.274713        51.564409       0.376325
# std    6.235377e+08   130.970799        49.652558       0.584221
# min    7.002735e+06     0.000000         0.000000       0.000000
# 25%    5.447600e+08    93.000000        18.000000       0.000000
# 50%    1.064159e+09   129.500000        38.000000       0.000000
# 75%    1.630364e+09   217.750000        72.000000       1.000000
# max    2.145741e+09  1235.000000       378.000000       4.000000
#
#        school_score  total_population  transit_rider_count  transit_score  \
# count    565.000000        566.000000           566.000000     566.000000
# mean      68.378761        669.818021           109.632509       5.787986
# std       44.493783        345.301085           164.775511       2.839219
# min        1.000000          0.000000             0.000000       1.000000
# 25%        8.000000        422.000000            18.250000       4.000000
# 50%      100.000000        659.000000            65.000000       6.000000
# 75%      100.000000        876.000000           137.000000       8.000000
# max      100.000000       2438.000000          1643.000000      10.000000
#
#        detour_score  overall_score  council_district         ward  \
# count    566.000000     573.000000       1106.000000  1106.000000
# mean       5.049470       5.551483          3.868897    18.009946
# std        3.054263       2.887074          2.262420     7.089147
# min        1.000000       1.000000          1.000000     0.000000
# 25%        2.000000       3.000000          2.000000    14.000000
# 50%        5.000000       6.000000          3.000000    19.000000
# 75%        8.000000       8.000000          6.000000    24.000000
# max       10.000000      10.000000          9.000000    32.000000
#
#               tract  public_works_division  pli_division  police_zone  \
# count  1.107000e+03            1106.000000   1106.000000  1106.000000
# mean   4.200330e+10               3.213382     18.009946     3.358951
# std    2.450798e+05               1.547335      7.089147     1.695481
# min    4.200301e+10               0.000000      0.000000     1.000000
# 25%    4.200316e+10               2.000000     14.000000     2.000000
# 50%    4.200319e+10               3.000000     19.000000     3.000000
# 75%    4.200332e+10               5.000000     24.000000     5.000000
# max    4.200398e+10               6.000000     32.000000     6.000000
#
#           latitude    longitude
# count  1107.000000  1107.000000
# mean     40.440109   -79.987495
# std       0.026940     0.041401
# min      40.370555   -80.074649
# 25%      40.420996   -80.018708
# 50%      40.438320   -79.991694
# 75%      40.461730   -79.960095
# max      40.494544   -79.871379

# %%
stairs_by_length = stairs.loc[:,["neighborhood", "length"]].groupby("neighborhood").sum()
stairs_by_length
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /opt/tljh/user/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3620             try:
# -> 3621                 return self._engine.get_loc(casted_key)
#    3622             except KeyError as err:
#
# /opt/tljh/user/lib/python3.8/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /opt/tljh/user/lib/python3.8/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('neighborhood', 'length')
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-6-5880521a8128> in <module>
#       1 #stairs_by_length = stairs[["neighborhood", "length"]].groupby("neighborhood").sum()
# ----> 2 stairs["neighborhood", "length"]
#
# /opt/tljh/user/lib/python3.8/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3503             if self.columns.nlevels > 1:
#    3504                 return self._getitem_multilevel(key)
# -> 3505             indexer = self.columns.get_loc(key)
#    3506             if is_integer(indexer):
#    3507                 indexer = [indexer]
#
# /opt/tljh/user/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3621                 return self._engine.get_loc(casted_key)
#    3622             except KeyError as err:
# -> 3623                 raise KeyError(key) from err
#    3624             except TypeError:
#    3625                 # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: ('neighborhood', 'length')

# %%
stairs_by_length.plot(kind='bar')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-f3b49f7f7f35> in <module>
# ----> 1 stairs_by_length.plot(kind='bar')
#
# NameError: name 'stairs_by_length' is not defined

# %% [markdown]
# Well that's just tremendously helpful. Let's do the top 5 longest lengths are, and then reduce our graph to just those:

# %%
top_five = stairs_by_length.sort_values(by = "length", ascending = False)[0:5]
top_five.plot(kind = "bar")

# %% [markdown]
# Well wouldn't you know - the neighborhood called "Slopes" has some slopes. Okay but that's just the length of the stairs - we still don't know if that means the population is more physically fit there. I mean, maybe there's just a guy there who really like stairs, and there's just stair models everywhere?
# ![stairs!](links/stairs.jpg)
# So let's divide the total lengths of the stairs by the respective populations of those neighborhoods:

# %%
stairs_by_pop = stairs[["neighborhood", "length","total_population"]].groupby("neighborhood").sum()
stairs_by_pop["weighted_length"] = (stairs_by_pop.length / stairs_by_pop.total_population)
top_five_weighted = stairs_by_pop.sort_values(by = "length", ascending = False)[0:5]
top_five_weighted
# Out:
#                     length  total_population  weighted_length
# neighborhood
# South Side Slopes  16335.0           49526.0         0.329827
# Beechview           9834.0           19605.0         0.501607
# Perry South         7284.0           12433.0         0.585860
# Mount Washington    5890.0           22174.0         0.265626
# Brookline           5806.0           14379.0         0.403783

# %% [markdown]
# That didn't help at all.

# %%
stairs[stairs["neighborhood"].isin(["Squirrel Hill"])]
# Out:
# Empty DataFrame
# Columns: [id, name, maintenance_responsibility, installed, material, length, number_of_steps, schools_count, school_score, total_population, transit_rider_count, transit_score, detour_score, overall_score, image, neighborhood, council_district, ward, tract, public_works_division, pli_division, police_zone, fire_zone, latitude, longitude]
# Index: []
#
# [0 rows x 25 columns]
