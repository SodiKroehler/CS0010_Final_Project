# %% [markdown]
# Jeremy Byrne (jeb430@pitt.edu)
#
# Initial analysis of dataset "City of Pittsburgh Courts and Rinks"
#
# I'm measuring what neighborhood has the most courts or rinks
#
# Count data of either has been made into a bar graph

# %%
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("courts_and_rinks.csv")

# %%
df['neighborhood'].value_counts().plot(kind='bar', figsize=(14,8),title="JBs Graph")
